# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
loan = pd.read_csv(r"C:\Users\user\Downloads\archive (2) (1)\Applicant-details.csv")
loan
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 0             75722        9657655             76                0
# 1             80185        9259353             37               18
# 2             19865        1509721             66                8
# 3             76700        5867312             43                1
# 4             92992        7223191             44                9
# ...             ...            ...            ...              ...
# 99995          6266         156398             69               10
# 99996         54887        1900932             69               11
# 99997         76821        6395936             66               11
# 99998           861        4505937             52                6
# 99999         15796        4186842             58                9
#
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0             single          rented                     no
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Applicant_ID                 100000 non-null  int64
#  1   Annual_Income                100000 non-null  int64
#  2   Applicant_Age                100000 non-null  int64
#  3   Work_Experience              100000 non-null  int64
#  4   Marital_Status               100000 non-null  object
#  5   House_Ownership              100000 non-null  object
#  6   Vehicle_Ownership(car)       100000 non-null  object
#  7   Occupation                   100000 non-null  object
#  8   Residence_City               100000 non-null  object
#  9   Residence_State              100000 non-null  object
#  10  Years_in_Current_Employment  100000 non-null  int64
#  11  Years_in_Current_Residence   100000 non-null  int64
# ...

# %%
loan.isna().sum()
# Out:
# Applicant_ID                   0
# Annual_Income                  0
# Applicant_Age                  0
# Work_Experience                0
# Marital_Status                 0
# House_Ownership                0
# Vehicle_Ownership(car)         0
# Occupation                     0
# Residence_City                 0
# Residence_State                0
# Years_in_Current_Employment    0
# Years_in_Current_Residence     0
# Loan_Default_Risk              0
# dtype: int64

# %%
loan.duplicated().sum()
# Out:
# 0

# %%
loan.nunique()
# Out:
# Applicant_ID                   100000
# Annual_Income                    5999
# Applicant_Age                      59
# Work_Experience                    21
# Marital_Status                      2
# House_Ownership                     3
# Vehicle_Ownership(car)              2
# Occupation                         51
# Residence_City                    317
# Residence_State                    29
# Years_in_Current_Employment        15
# Years_in_Current_Residence          5
# Loan_Default_Risk                   2
# dtype: int64

# %%
loan.columns
# Out:
# Index(['Applicant_ID', 'Annual_Income', 'Applicant_Age', 'Work_Experience',
#        'Marital_Status', 'House_Ownership', 'Vehicle_Ownership(car)',
#        'Occupation', 'Residence_City', 'Residence_State',
#        'Years_in_Current_Employment', 'Years_in_Current_Residence',
#        'Loan_Default_Risk'],
#       dtype='object')

# %%
loan.describe()
# Out:
#         Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# count  100000.000000   1.000000e+05  100000.000000    100000.000000
# mean    50000.500000   5.001617e+06      49.995400        10.110750
# std     28867.657797   2.876394e+06      17.056051         5.996007
# min         1.000000   1.031000e+04      21.000000         0.000000
# 25%     25000.750000   2.507092e+06      35.000000         5.000000
# 50%     50000.500000   5.004938e+06      50.000000        10.000000
# 75%     75000.250000   7.477502e+06      65.000000        15.000000
# max    100000.000000   9.999180e+06      79.000000        20.000000
#
#        Years_in_Current_Employment  Years_in_Current_Residence  \
# count                100000.000000               100000.000000
# mean                      6.342990                   11.996020
# std                       3.644942                    1.396826
# min                       0.000000                   10.000000
# ...

# %%
loan.head()
# Out:
#    Applicant_ID  Annual_Income  Applicant_Age  Work_Experience Marital_Status  \
# 0         75722        9657655             76                0         single
# 1         80185        9259353             37               18         single
# 2         19865        1509721             66                8         single
# 3         76700        5867312             43                1         single
# 4         92992        7223191             44                9         single
#
#   House_Ownership Vehicle_Ownership(car)              Occupation  \
# 0          rented                     no            Psychologist
# 1          rented                     no      Petroleum_Engineer
# 2          rented                     no                 Drafter
# 3           owned                     no    Chartered_Accountant
# 4          rented                     no  Air_traffic_controller
#
#   Residence_City Residence_State  Years_in_Current_Employment  \
# ...

# %%
loan=loan.drop(["Applicant_ID","Residence_City","Residence_State"], axis = 1)
loan
# Out:
#        Annual_Income  Applicant_Age  Work_Experience Marital_Status  \
# 0            9657655             76                0         single
# 1            9259353             37               18         single
# 2            1509721             66                8         single
# 3            5867312             43                1         single
# 4            7223191             44                9         single
# ...              ...            ...              ...            ...
# 99995         156398             69               10         single
# 99996        1900932             69               11         single
# 99997        6395936             66               11         single
# 99998        4505937             52                6         single
# 99999        4186842             58                9         single
#
#       House_Ownership Vehicle_Ownership(car)              Occupation  \
# 0              rented                     no            Psychologist
# ...

# %%
sns.countplot(x="House_Ownership",data = loan) 
plt.title("Count of House Ownership", fontdict = {"fontsize":20})
plt.show()

# %%
loan.head(3)
# Out:
#    Annual_Income  Applicant_Age  Work_Experience Marital_Status  \
# 0        9657655             76                0         single
# 1        9259353             37               18         single
# 2        1509721             66                8         single
#
#   House_Ownership Vehicle_Ownership(car)          Occupation  \
# 0          rented                     no        Psychologist
# 1          rented                     no  Petroleum_Engineer
# 2          rented                     no             Drafter
#
#    Years_in_Current_Employment  Years_in_Current_Residence  Loan_Default_Risk
# 0                            0                          12                  0
# 1                           12                          11                  0
# 2                            4                          12                  0

# %%
sns.heatmap(loan.corr(), cbar = True, linewidth = 0.5)
plt.show()

# %%
#To determine the number of rented,own and no rented/owned homes.
loan["House_Ownership"].value_counts()
# Out:
# rented          92088
# owned            5081
# norent_noown     2831
# Name: House_Ownership, dtype: int64

# %% [markdown]
# The number of rented houses is 92088,owned is 5081,and  not rented or owned is 2831

# %%
sns.barplot(x = "Marital_Status",  y= "Loan_Default_Risk", data = loan)
plt.ylabel("Loan Default Risk")
plt.xlabel("Marital Status")
plt.title("Marital status vs Loan Default Risk")
plt.show()

# %% [markdown]
# The single people are mostly likely to default loan with the risk at 0.13 while the married one with the risk at 0.11.

# %%
sns.barplot(x = "House_Ownership",  y= "Loan_Default_Risk", data = loan)
plt.ylabel("Loan Default Risk")
plt.xlabel("House Ownership")
plt.title("House Ownership vs Loan Default Risk")
plt.show()

# %% [markdown]
# Those in the rented houses are more likely to default the loan with the risk at 0.13 while those with owned and not rented or owned at the risk of 0.09

# %%
sns.barplot(x = loan["Vehicle_Ownership(car)"], y= "Loan_Default_Risk", data = loan)
plt.ylabel("Loan Default Risk")
plt.xlabel("Vehicle Ownership")
plt.title("Vehicle Ownership vs Loan Default Risk")
plt.show()

# %% [markdown]
# Those without cars are likely to default loan with the risk slighlty higher than 0.14
